# %%
import pandas as pd
data = pd.read_csv("seattle_pet_licenses.csv", delimiter=',')
data
# Out:
#       animal_s_name       license_issue_date  license_number  \
# 0              Ozzy  2005-03-29T00:00:00.000        130651.0
# 1              Jack  2009-12-23T00:00:00.000        898148.0
# 2            Ginger  2006-01-20T00:00:00.000         29654.0
# 3            Pepper  2006-02-07T00:00:00.000         75432.0
# 4              Addy  2006-08-04T00:00:00.000        729899.0
# ...             ...                      ...             ...
# 66037          Lily  2016-12-27T00:00:00.000             NaN
# 66038         Ellie  2016-11-29T00:00:00.000             NaN
# 66039         Sammy  2016-12-05T00:00:00.000             NaN
# 66040         Buddy  2016-12-06T00:00:00.000             NaN
# 66041           Aku  2016-12-07T00:00:00.000             NaN
#
#                            primary_breed      secondary_breed species zip_code
# 0      Dachshund, Standard Smooth Haired                  NaN     Dog    98104
# ...

# %%
data['species'].value_counts()
# Out:
# Dog          43076
# Cat          22915
# Livestock       51
# Name: species, dtype: int64

# %%
dogs = data[data['species'] == 'Dog']
dogs
# Out:
#       animal_s_name       license_issue_date  license_number  \
# 0              Ozzy  2005-03-29T00:00:00.000        130651.0
# 1              Jack  2009-12-23T00:00:00.000        898148.0
# 2            Ginger  2006-01-20T00:00:00.000         29654.0
# 4              Addy  2006-08-04T00:00:00.000        729899.0
# 5            Rustie  2007-07-24T00:00:00.000        437433.0
# ...             ...                      ...             ...
# 66031        Bonita  2016-12-22T00:00:00.000             NaN
# 66038         Ellie  2016-11-29T00:00:00.000             NaN
# 66039         Sammy  2016-12-05T00:00:00.000             NaN
# 66040         Buddy  2016-12-06T00:00:00.000             NaN
# 66041           Aku  2016-12-07T00:00:00.000             NaN
#
#                            primary_breed      secondary_breed species zip_code
# 0      Dachshund, Standard Smooth Haired                  NaN     Dog    98104
# ...

# %%
cats = data[data['species'] == 'Cat']
cats
# Out:
#       animal_s_name       license_issue_date  license_number  \
# 3            Pepper  2006-02-07T00:00:00.000         75432.0
# 7             Emily  2007-11-19T00:00:00.000        895915.0
# 14           Hunter  2008-08-02T00:00:00.000        352920.0
# 32           Skyler  2011-03-28T00:00:00.000        134722.0
# 42     Mister Kitty  2012-02-10T00:00:00.000         81952.0
# ...             ...                      ...             ...
# 66033           boy  2016-11-25T00:00:00.000             NaN
# 66034           NaN  2016-11-25T00:00:00.000             NaN
# 66035           NaN  2016-11-25T00:00:00.000             NaN
# 66036           NaN  2016-11-26T00:00:00.000             NaN
# 66037          Lily  2016-12-27T00:00:00.000             NaN
#
#               primary_breed secondary_breed species zip_code
# 3                      Manx             Mix     Cat    98103
# 7      Domestic Medium Hair             NaN     Cat    98103
# ...

# %%
Livestock = data[data['species'] == 'Livestock']
Livestock
# Out:
#                 animal_s_name       license_issue_date  license_number  \
# 10643                  Eloise  2015-06-05T00:00:00.000        214413.0
# 10718                   Holly  2015-05-12T00:00:00.000        282091.0
# 10719               Priscilla  2015-05-12T00:00:00.000        282092.0
# 19653                 Phyllis  2015-07-11T00:00:00.000        432423.0
# 19654                   Rosie  2015-07-11T00:00:00.000        432424.0
# 20377                 Pegasis  2015-12-01T00:00:00.000        828693.0
# 20410                  Amanda  2015-12-01T00:00:00.000        828692.0
# 20786                 Abelard  2015-07-31T00:00:00.000        443495.0
# 24122                   Minty  2015-10-05T00:00:00.000        834015.0
# 24230                  Moppet  2015-12-01T00:00:00.000        903797.0
# 25087                   Willi  2015-10-05T00:00:00.000        834013.0
# 26376                   Olive  2015-07-31T00:00:00.000        443496.0
# ...

# %%
data['species'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='species'>

# %%
data['species'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
data['primary_breed'].value_counts()
# Out:
# Domestic Shorthair            13134
# Retriever, Labrador            6350
# Domestic Medium Hair           3020
# Retriever, Golden              2321
# Chihuahua, Short Coat          2134
#                               ...
# Terrier, Skye                     1
# Terrier, American Hairless        1
# Braque Francais Gascogne          1
# Maremma Sheepdog                  1
# Azores Cattle Dog                 1
# Name: primary_breed, Length: 323, dtype: int64

# %%
data['primary_breed'].value_counts().head(15)
# Out:
# Domestic Shorthair            13134
# Retriever, Labrador            6350
# Domestic Medium Hair           3020
# Retriever, Golden              2321
# Chihuahua, Short Coat          2134
# Domestic Longhair              1916
# German Shepherd                1259
# Australian Shepherd            1184
# Terrier                        1119
# American Shorthair              992
# Border Collie                   991
# Siamese                         977
# Terrier, American Pit Bull      973
# Poodle, Miniature               929
# Shih Tzu                        828
# Name: primary_breed, dtype: int64

# %%
breedDog = data['primary_breed'].value_counts().head(15)
breedDog
# Out:
# Domestic Shorthair            13134
# Retriever, Labrador            6350
# Domestic Medium Hair           3020
# Retriever, Golden              2321
# Chihuahua, Short Coat          2134
# Domestic Longhair              1916
# German Shepherd                1259
# Australian Shepherd            1184
# Terrier                        1119
# American Shorthair              992
# Border Collie                   991
# Siamese                         977
# Terrier, American Pit Bull      973
# Poodle, Miniature               929
# Shih Tzu                        828
# Name: primary_breed, dtype: int64

# %%
dogs.value_counts().head(15)
# Out:
# animal_s_name  license_issue_date       license_number  primary_breed               secondary_breed        species  zip_code
# Dolkar         2015-11-19T00:00:00.000  902530.0        Schnauzer, Miniature        Poodle, Miniature      Dog      98133       3
# Soozy          2015-11-13T00:00:00.000  959833.0        Terrier, Welsh              Welsh Corgi, Pembroke  Dog      98122       3
# Bonny          2013-12-03T00:00:00.000  214753.0        Terrier, Cairn              Poodle, Miniature      Dog      98102       2
# Barkley        2013-08-29T00:00:00.000  585696.0        Retriever, Labrador         Rottweiler             Dog      98115       2
# Coos           2013-06-11T00:00:00.000  281593.0        Australian Shepherd         Retriever, Labrador    Dog      98107       2
# Lucky          2013-08-20T00:00:00.000  354884.0        Australian Shepherd         Border Collie          Dog      98144       2
# ...

# %%
dogs['primary_breed'].value_counts().head(15)
# Out:
# Retriever, Labrador           6350
# Retriever, Golden             2321
# Chihuahua, Short Coat         2134
# German Shepherd               1259
# Australian Shepherd           1184
# Terrier                       1119
# Border Collie                  991
# Terrier, American Pit Bull     973
# Poodle, Miniature              929
# Shih Tzu                       828
# Pug                            819
# Xoloitzcuintli                 795
# Beagle                         744
# Australian Cattle Dog          728
# Terrier, Yorkshire             690
# Name: primary_breed, dtype: int64

# %%
cats['primary_breed'].value_counts().head(15)
# Out:
# Domestic Shorthair      13134
# Domestic Medium Hair     3020
# Domestic Longhair        1916
# American Shorthair        992
# Siamese                   977
# LaPerm                    752
# Maine Coon                394
# Ragdoll                   187
# Mix                       184
# Russian Blue              171
# Persian                   125
# Manx                      111
# Bengal                     98
# Siberian                   77
# Himalayan                  73
# Name: primary_breed, dtype: int64

# %%
Livestock['primary_breed'].value_counts().head(15)
# Out:
# Miniature      44
# Pot-Bellied     4
# Standard        2
# Pot Bellied     1
# Name: primary_breed, dtype: int64

# %%
dogs['primary_breed'].value_counts().head(15).plot.pie()
# Out:
# <AxesSubplot:ylabel='primary_breed'>

# %%
cats['primary_breed'].value_counts().head(15).plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
Livestock['primary_breed'].value_counts().head(15).plot(kind = 'barh')
# Out:
# <AxesSubplot:>
